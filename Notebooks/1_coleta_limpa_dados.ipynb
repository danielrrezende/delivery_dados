# %% [markdown]
# # Sobre os dados
#
# Como uma empresa orientada para a comunidade, apreciamos o uso de dados abertos em nossa análise. Portanto, para este
# teste, queremos que você baixe e seja criativo em sua análise sobre Open Ocean Data do
# Digital Ocean Institute da Irlanda.

# %%
from pyspark.sql.functions import *
from pyspark.context import SparkContext
from pyspark.sql.session import SparkSession
from pyspark.sql.types import IntegerType, FloatType, DoubleType, DateType, TimestampType, StringType
from pyspark.sql import functions as F
from pyspark.sql.window import Window

import pandas as pd

from datetime import date, datetime, timedelta

from pandas_profiling import ProfileReport

import plotly.express as px
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# converte mes numerico pra string
def func(month):
    if month == 1: return 'JAN'
    if month == 2: return 'FEB'
    if month == 3: return 'MAR'
    if month == 4: return 'APR'
    if month == 5: return 'MAY'
    if month == 6: return 'JUN'
    if month == 7: return 'JUL'
    if month == 8: return 'AUG'
    if month == 9: return 'SEP'
    if month == 10: return 'OCT'
    if month == 11: return 'NOV'
    if month == 12: return 'DEC'
    return month

# funcção converte string para datetime
func_time_datetime =  udf (lambda x: datetime.strptime(x, '%Y-%m-%dT%H:%M:%SZ'), DateType())

# funcção converte string para datetime
func_time_stamp =  udf (lambda x: datetime.strptime(x, '%Y-%m-%dT%H:%M:%SZ'), TimestampType())
func_time_stamp_simples =  udf (lambda x: datetime.strptime(x, '%Y-%m-%d'), TimestampType())

# funcção converte string para datetime
func_time_string =  udf (lambda x: datetime.strptime(x, '%Y-%m-%d'), StringType())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ***

# %% [markdown]
# ## 1.1) Entendendo os dados
#
# Uma análise sobre Open Ocean Data do Digital Ocean Institute da Irlanda.
#
#
# **Intervalo de tempo:** \
# Análise feita num intervalo de 1 ano, do dia 21/09/2021 a 21/09/2022.

# %% [markdown]
# ***

# %% [markdown]
# ## 1.2) Coleta de dados

# %% [markdown]
# ### Tides - Marés
# Medidas sobre Marés coletadas por várias bóias no mar da Irlanda
#
# Time - UTC \
# Station ID \
# Latitude - degrees_north \
# Longitude - degrees_east \
# Water Level (LAT) - meters \
# Water Level (OD Malin) - meters \
# Quality Control Flag

# %%
# File location and type
file_location_td = "/FileStore/tables/tide/*.csv"

# The applied options are for CSV files. For other file types, these will be ignored.
df_tides = spark.read.format('csv') \
                .option("inferSchema", 'true') \
                .option("header", 'true') \
                .option("sep", ',') \
                .load(file_location_td)\
                .drop_duplicates()

# remove a primeira linha que possui dados discrepantes do resto da base
df_tides = df_tides.filter(~col("time").contains(df_tides.first()[0]))

# convert types
df_tides = df_tides.withColumn("latitude", df_tides["latitude"].cast(FloatType()))\
                   .withColumn("longitude", df_tides["longitude"].cast(FloatType()))\
                   .withColumn("Water_Level_LAT", df_tides["Water_Level_LAT"].cast(FloatType()))\
                   .withColumn("Water_Level_OD_Malin", df_tides["Water_Level_OD_Malin"].cast(FloatType()))\

display(df_tides)
df_tides.count()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>time</th><th>station_id</th><th>latitude</th><th>longitude</th><th>Water_Level_LAT</th><th>Water_Level_OD_Malin</th><th>QC_Flag</th></tr></thead><tbody><tr><td>2021-09-20T22:35:00Z</td><td>Aranmore Island - Leabgarrow</td><td>54.9905</td><td>-8.4955</td><td>0.718</td><td>-1.485</td><td>1</td></tr><tr><td>2021-09-21T20:15:00Z</td><td>Aranmore Island - Leabgarrow</td><td>54.9905</td><td>-8.4955</td><td>3.264</td><td>1.061</td><td>1</td></tr><tr><td>2021-09-22T18:55:00Z</td><td>Aranmore Island - Leabgarrow</td><td>54.9905</td><td>-8.4955</td><td
killybegs Port</td><td>54.6364</td><td>-8.3949</td></tr><tr><td>Ballycotton Harbour</td><td>51.8278</td><td>-8.0007</td></tr><tr><td>Rosslare</td><td>52.2546</td><td>-6.334861</td></tr><tr><td>Sligo</td><td>54.3099</td><td>-8.582</td></tr><tr><td>Malin Head - Portmore Pier</td><td>55.3717</td><td>-7.3344</td></tr><tr><td>Skerries Harbour</td><td>53.585</td><td>-6.1081</td></tr><tr><td>Kinvara - Unreferenced</td><td>53.14052</td><td>-8.93758</td></tr></tbody></table></div>

# %% [markdown]
# ***

# %% [markdown]
# ### Waves - Ondas
# Medidas sobre Ondas coletadas por várias bóias no mar da Irlanda
#
#
# Time - UTC\
# Station_id \
# Latitude - degrees_north \
# Longitude - degrees_east \
# Peak Period - S\
# Peak Direction - degrees_true\
# Upcross Period - S\
# Significant Wave Height - cm\
# Maximum Wave Height - cm\
# Sea Temperature - degree_C\
# Current Speed - m/s\
# Current Direction - degrees_true

# %%
# File location and type
file_location_wv = "/FileStore/tables/wave/*.csv"

# The applied options are for CSV files. For other file types, these will be ignored.
df_waves = spark.read.format('csv') \
                .option("inferSchema", 'true') \
                .option("header", 'true') \
                .option("sep", ',') \
                .load(file_location_wv) \
                .drop_duplicates()\
                .select('time', 'station_id', 'latitude', 'longitude', 'PeakPeriod', 'PeakDirection', 'UpcrossPeriod', 'SignificantWaveHeight', 'Hmax', 
                        'SeaTemperature', 'MeanCurSpeed', 'MeanCurDirTo')

# remove a primeira linha que possui dados discrepantes do resto da base
df_waves = df_waves.filter(~col("time").contains(df_waves.first()[0]))

# convert types
df_waves = df_waves.withColumn("latitude", df_waves["latitude"].cast(FloatType()))\
                   .withColumn("longitude", df_waves["longitude"].cast(FloatType()))\
                   .withColumn("PeakPeriod", df_waves["PeakPeriod"].cast(FloatType()))\
                   .withColumn("PeakDirection", df_waves["PeakDirection"].cast(FloatType()))\
                   .withColumn("UpcrossPeriod", df_waves["UpcrossPeriod"].cast(FloatType()))\
                   .withColumn("SignificantWaveHeight", df_waves["SignificantWaveHeight"].cast(FloatType()))\
                   .withColumn("Hmax", df_waves["Hmax"].cast(FloatType()))\
                   .withColumn("SeaTemperature", df_waves["SeaTemperature"].cast(FloatType()))\
                   .withColumn("MeanCurSpeed", df_waves["MeanCurSpeed"].cast(FloatType()))\
                   .withColumn("MeanCurDirTo", df_waves["MeanCurDirTo"].cast(FloatType()))\

display(df_waves)
df_waves.count()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>time</th><th>station_id</th><th>latitude</th><th>longitude</th><th>PeakPeriod</th><th>PeakDirection</th><th>UpcrossPeriod</th><th>SignificantWaveHeight</th><th>Hmax</th><th>SeaTemperature</th><th>MeanCurSpeed</th><th>MeanCurDirTo</th></tr></thead><tbody><tr><td>2021-09-23T07:00:00Z</td><td>Bantry Bay</td><td>51.647</td><td>-9.681</td><td>6.25</td><td>239.9121</td><td>2.89</td><td>40.0</td><td>59.0</td><td>17.01</td><td>NaN</td><td>NaN</td></tr><tr><td>2021-09-23T09:40:00Z</td><td>Bantry Bay</td><td>51.647</td><td>-9.681</td><td>NaN</td><td>NaN</td><td>NaN</td><td>NaN</td><td>NaN</td><td>17.23</td><td>NaN</td><td>NaN</td></tr><tr><td>2021-09-23T12:45:00Z</td><td>Bantry Bay</td><td>51.647</td><td>-9.681</td><td>NaN</td><td>NaN</td><td>NaN</td><td>NaN</td><td>NaN</td><td>17.74</td><td>NaN</td><td>NaN</td></tr><tr><td>2021-09-22T00:25:00Z</td><td>Bantry Bay</td><td>51.647</td><td>-9.681</td><td>NaN</td><td>NaN</td><td>NaN</td><td>NaN</td><td>NaN</td><td>16.84</td><td>NaN</td><td>NaN</td></tr><tr><td>2021-09-22T01:05:00Z</td><td>Bantry Bay</td><td>51.647</td><td>-9.681</td><td>NaN</td><td>NaN</td><td>NaN</td><td>NaN</td><td>NaN</td><td>16.84</td><td>NaN</td><td>NaN</td></tr><tr><td>2021-09-22T06:55:00Z</td><td>Bantry Bay</td><td>51.647</td><td>-9.681</td><td>NaN</td><td>NaN</td><td>NaN</td><td>NaN</td><td>NaN</td><td>16.89</td><td>NaN</td><td>NaN</td></tr><tr><td>2021-09-22T09:05:00Z</td><td>Bantry Bay</td><td>51.647</td><td>-9.681</td><td>NaN</td><td>NaN</td><td>NaN</td><td>NaN</td><td>NaN</td><td>17.01</td><td>NaN</td><td>NaN</td></tr><tr><td>2021-09-22T11:45:00Z</td><td>Bantry Bay</td><td>51.647</td><td>-9.681</td><td>NaN</td><td>NaN</td><td>NaN</td><td>NaN</td><td>NaN</td><td>17.1</td><td>NaN</td><td>NaN</td></tr><tr><td>2021-09-24T12:30:00Z</td><td>Bantry Bay</td><td>51.647</td><td>-9.681</td><td>11.76</td><td>257.93405</td><td>3.24</td><td>54.0</td><td>72.0</td><td>17.74</td><td>NaN</td><td>NaN</td></tr><tr><td>2021-09-24T12:45:00Z</td><td>Bantry Bay</td><td>51.647</td><td>-9.681</td><td>NaN</td><td>NaN</td><td>NaN</td><td>NaN</td><td>NaN</td><td>17.69</td><td>NaN</td><td>NaN</td></tr><tr><td>2021-09-24T21:30:00Z</td><td>Bantry Bay</td><td>51.647</td><td>-9.681</td><td>10.53</td><td>257.05493</td><td>2.93</td><td>41.0</td><td>60.0</td><td>17.48</td><td>NaN</td><td>NaN</td></tr><tr><td>2021-09-22T03:30:00Z</td><td>Bantry Bay</td><td>51.647</td><td>-9.681</td><td>6.67</td><td>243.6044</td><td>2.8</td><td>32.0</td><td>51.0</td><td>16.89</td><td>NaN</td><td>NaN</td></tr><tr><td>2021-09-24T16:45:00Z</td><td>Bantry Bay</td><td>51.647</td><td>-9.681</td><td>NaN</td><td>NaN</td><td>NaN</td><td>NaN</td><td>NaN</td><td>17.57</td><td>NaN</td><td>NaN</td></tr><tr><td>2021-09-22T04:10:00Z</td><td>Bantry Bay</td><td>51.647</td><td>-9.681</td><td>NaN</td><td>NaN</td><td>NaN</td><td>NaN</td><td>NaN</td><td>16.84</td><td>NaN</td><td>NaN</td></tr><tr><td>2021-09-22T06:10:00Z</td><td>Bantry Bay</td><td>51.647</td><td>-9.681</td><td>NaN</td><td>NaN</td><td>NaN</td><td>NaN</td><td>NaN</td><td>16.89</td><td>NaN</td><td>NaN</td></tr><tr><td>2021-09-22T11:35:00Z</td><td>Bantry Bay</td><td>51.647</td><td>-9.681</td><td>NaN</td><td>NaN</td><td>NaN</td><td>NaN</td><td>NaN</td><td>17.1</td><td>NaN</td><td>NaN</td></tr><tr><td>2021-09-23T08:55:00Z</td><td>Bantry Bay</td><td>51.647</td><td>-9.681</td><td>NaN</td><td>NaN</td><td>NaN</td><td>NaN</td><td>NaN</td><td>17.23</td><td>NaN</td><td>NaN</td></tr><tr><td>2021-09-23T11:05:00Z</td><td>Bantry Bay</td><td>51.647</td><td>-9.681</td><td>NaN</td><td>NaN</td><td>NaN</td><td>NaN</td><td>NaN</td><td>17.44</td><td>NaN</td><td>NaN</td></tr><tr><td>2021-09-23T16:15:00Z</td><td>Bantry Bay</td><td>51.647</td><td>-9.681</td><td>NaN</td><td>NaN</td><td>NaN</td><td>NaN</td><td>NaN</td><td>17.74</td><td>NaN</td><td>NaN</td></tr><tr><td>2021-09-23T23:30:00Z</td><td>Bantry Bay</td><td>51.647</td><td>-9.6 ...
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: 247892</div>

# %% [markdown]
# #### Estações na base de dados
#
# Observaçao: estacoes AMETS Berth B Wave Buoy e Westwave Wave Buoy estava com sua base de dados vazia

# %%
# df_waves.station_id.unique()
display(df_waves.select('station_id', 'latitude', 'longitude').distinct())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>station_id</th><th>latitude</th><th>longitude</th></tr></thead><tbody><tr><td>Bantry Bay</td><td>51.647</td><td>-9.681</td></tr><tr><td>SmartBay Wave Buoy</td><td>53.228333</td><td>-9.262278</td></tr><tr><td>AMETS Berth A Wave Buoy</td><td>54.2753</td><td>-10.29737</td></tr><tr><td>Brandon Bay</td><td>52.282333</td><td>-10.094833</td></tr><tr><td>Clew Bay</td><td>53.801353</td><td>-9.911498</td></tr><tr><td>AMETS Berth B Wave Buoy</td><td>54.2251</td><td>-10.15099</td></tr></tbody></table></div>

# %% [markdown]
# ***

# %% [markdown]
# ## 1.3) Limpeza dos dados

# %% [markdown]
# ### Tides

# %%
df_tides.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: 1747240</div>

# %%
df_tides.select(*[(
                   F.count(F.when((F.isnan(c) | F.col(c).isNull()), c)) if t not in ("timestamp", "date")
                   else F.count(F.when(F.col(c).isNull(), c))
                  ).alias(c)
                  for c, t in df_tides.dtypes if c in df_tides.columns
                 ]).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+----------+--------+---------+---------------+--------------------+-------+
# time|station_id|latitude|longitude|Water_Level_LAT|Water_Level_OD_Malin|QC_Flag|
# +----+----------+--------+---------+---------------+--------------------+-------+
#    0|         0|       0|        0|         246408|                   0|      0|
# +----+----------+--------+---------+---------------+--------------------+-------+
#
# </div>

# %% [markdown]
# ### Waves

# %%
df_waves.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: 247892</div>

# %%
df_waves.select(*[(
                   F.count(F.when((F.isnan(c) | F.col(c).isNull()), c)) if t not in ("timestamp", "date")
                   else F.count(F.when(F.col(c).isNull(), c))
                  ).alias(c)
                  for c, t in df_waves.dtypes if c in df_waves.columns
                 ]).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+----------+--------+---------+----------+-------------+-------------+---------------------+------+--------------+------------+------------+
# time|station_id|latitude|longitude|PeakPeriod|PeakDirection|UpcrossPeriod|SignificantWaveHeight|  Hmax|SeaTemperature|MeanCurSpeed|MeanCurDirTo|
# +----+----------+--------+---------+----------+-------------+-------------+---------------------+------+--------------+------------+------------+
#    0|         0|       0|        0|    170952|       170952|       170952|               170952|213736|             0|      195063|      195066|
# +----+----------+--------+---------+----------+-------------+-------------+---------------------+------+--------------+------------+------------+
#
# </div>
